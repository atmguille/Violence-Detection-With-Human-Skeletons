# %%
DATASET = 'hockey'

# %%
# Use output of OpenPose without background
# Paths to videos for training
PATHS = [f"../datasets/{DATASET}_dataset/original_data/", f"../datasets/{DATASET}_dataset/openpose_gamma/"]

FRAME_FUNC = 'frame_diff'
# To use frame diff to weight t (current) or t+1
WEIGHT_CURRENT = True

# %%
import tensorflow as tf

# %%
# !export TF_FORCE_GPU_ALLOW_GROWTH=True
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.config.set_visible_devices(gpus[0:1], 'GPU')
# Out:
# 2022-07-26 05:48:16.398466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.401931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.403460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.409034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.411159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.412523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.412980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.415020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.416411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# Set seed

# %%
SEED = 0
import random
import numpy as np
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # Load data

# %%
import numpy as np
import cv2

# %%
FRAMES_PER_VIDEO = 50 + 1
VIDEO_WIDTH, VIDEO_HEIGHT = 100, 100
N_CHANNELS = 3

def load_videos(video_IDs: list, video_frames: int = FRAMES_PER_VIDEO, video_width: int = VIDEO_WIDTH, video_height: int = VIDEO_HEIGHT,
                video_channels: int = N_CHANNELS, dtype = np.float32, normalize: bool = False) -> tuple:
    videos = np.empty((len(video_IDs), video_frames, video_height, video_width, video_channels), dtype=dtype)

    for i, video_ID in enumerate(video_IDs):
        cap = cv2.VideoCapture(video_ID)
        original_n_frames = int(cap. get(cv2. CAP_PROP_FRAME_COUNT))
        
        # Indexes of frames to be kept to comply with video_frames
        frames_idx = set(np.round(np.linspace(0, original_n_frames - 1, video_frames)).astype(int))

        frames = []
        index = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            if index in frames_idx:
                frame = cv2.resize(frame, (video_width, video_height)).astype(dtype)
                if normalize:
                    frame /= 255.0
                frames.append(frame)
            index += 1
        cap.release()

        if len(frames) != video_frames:
            # Complete with repeated frames in the begging and the end of the video
            n_repeats = (video_frames - len(frames)) / 2
            # In case n_repeats is decimal, first frames will be rounded to the nearest integer
            beggining_frames = np.tile(frames[0], [round(n_repeats + 0.001), 1, 1, 1])
            end_frames = np.tile(frames[-1], [int(n_repeats), 1, 1, 1])
            frames = np.concatenate([beggining_frames, frames, end_frames])
        
        videos[i,] = np.array(frames)
        

    return videos

# %% [markdown]
# DataGenerator class to load videos per batch, in case all videos do not fit in memory

# %%
import gc
from tensorflow.keras import backend as K

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, video_IDs: list, video_labels: list, batch_size: int, paths: list = [''], video_width: int = VIDEO_WIDTH, video_height: int = VIDEO_HEIGHT,
                video_frames: int = FRAMES_PER_VIDEO, video_channels: int = N_CHANNELS, dtype = np.float32, normalize: bool = False, shuffle: bool = True):
        self.video_IDs = video_IDs
        self.video_labels = video_labels
        self.batch_size = batch_size
        self.paths = paths
        self.video_width = video_width
        self.video_height = video_height
        self.video_frames = video_frames
        self.video_channels = video_channels
        self.dtype = dtype
        self.normalize = normalize
        self.shuffle = shuffle

    def __len__(self):
        return len(self.video_IDs) // self.batch_size

    def __getitem__(self, idx):
        batch_IDs = self.video_IDs[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_labels = self.video_labels[idx*self.batch_size:(idx+1)*self.batch_size]
        input_videos = []
        
        for index, path in enumerate(self.paths):
            batch_IDs_full_path = [path+ID for ID in batch_IDs]

            videos = load_videos(batch_IDs_full_path, self.video_frames, self.video_width, 
                                         self.video_height, self.video_channels, self.dtype, self.normalize)
            
            input_videos.append(videos)
                    
        return input_videos, batch_labels
            
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            # shuffle video_IDs and video_labels together
            temp_list = list(zip(self.video_IDs, self.video_labels))
            np.random.shuffle(temp_list)
            self.video_IDs, self.video_labels = zip(*temp_list)
        # Clear memory after epochs
        gc.collect()
        #K.clear_session()

# %% [markdown]
# ## Videos to load

# %%
import pandas as pd
folds = pd.read_csv(f'../datasets/{DATASET}_dataset/folds.csv')

def fecth_generators(fold):

    train_df = folds[folds.fold != fold]
    test_df = folds[folds.fold == fold]

    train_video_IDs = train_df.video.values
    test_video_IDs = test_df.video.values

    train_video_labels = train_df.label.values
    test_video_labels = test_df.label.values

    train_generator = DataGenerator(train_video_IDs, train_video_labels, batch_size=10, paths=PATHS)
    test_generator = DataGenerator(test_video_IDs, test_video_labels, batch_size=10, paths=PATHS)

    return train_generator, test_generator

# %% [markdown]
# # Frame functions

# %%
import tensorflow.keras.backend as K

def tf_frame_diff(video):
    return video[1:] - video[:-1]

frame_func = tf_frame_diff

# %% [markdown]
# # Load pretrained best model without optimizer

# %%
cv_acc = 0.0

for fold in range(5):
    print('#'*10, 'Fold', fold, '#'*10)

    model = tf.keras.models.load_model('models/rwf_best_model_no_optimizer.h5')
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=f'models/{DATASET}_best_model_fold{fold}.h5',
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)

    train_generator, test_generator = fecth_generators(fold)
    history = model.fit(train_generator, epochs=5, validation_data=test_generator, verbose=2, callbacks=[model_checkpoint_callback])

    fold_acc = max(history.history['val_accuracy'])
    print('#'*10, f'Fold {fold} accuracy:', fold_acc, '#'*10)
    cv_acc += fold_acc / 5
# Out:
# ########## Fold 0 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-07-26 05:48:16.517386: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-26 05:48:16.519956: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.522079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.524130: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.884521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.886628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.888714: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:48:16.890797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79112 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:01:00.0, compute capability: 8.0
# Epoch 1/5
# 2022-07-26 05:48:21.227168: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8204
# 2022-07-26 05:48:22.101978: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-07-26 05:48:22.103852: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2022-07-26 05:48:22.103882: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-07-26 05:48:22.104005: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-07-26 05:48:22.964283: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 80/80 - 52s - loss: 0.6048 - accuracy: 0.7738 - val_loss: 0.4136 - val_accuracy: 0.8500 - 52s/epoch - 647ms/step
# Epoch 2/5
# 80/80 - 46s - loss: 0.3419 - accuracy: 0.8637 - val_loss: 0.2842 - val_accuracy: 0.9000 - 46s/epoch - 570ms/step
# Epoch 3/5
# 80/80 - 46s - loss: 0.2857 - accuracy: 0.8938 - val_loss: 0.2438 - val_accuracy: 0.9150 - 46s/epoch - 572ms/step
# Epoch 4/5
# 80/80 - 46s - loss: 0.2562 - accuracy: 0.9025 - val_loss: 0.2592 - val_accuracy: 0.9300 - 46s/epoch - 570ms/step
# Epoch 5/5
# 80/80 - 46s - loss: 0.2212 - accuracy: 0.9250 - val_loss: 0.3269 - val_accuracy: 0.8900 - 46s/epoch - 569ms/step
# ########## Fold 0 accuracy: 0.9300000071525574 ##########
# ########## Fold 1 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/5
# 80/80 - 49s - loss: 0.5432 - accuracy: 0.7738 - val_loss: 0.4062 - val_accuracy: 0.8450 - 49s/epoch - 615ms/step
# Epoch 2/5
# 80/80 - 45s - loss: 0.3666 - accuracy: 0.8462 - val_loss: 0.2635 - val_accuracy: 0.8950 - 45s/epoch - 568ms/step
# Epoch 3/5
# 80/80 - 46s - loss: 0.2792 - accuracy: 0.8950 - val_loss: 0.1869 - val_accuracy: 0.9350 - 46s/epoch - 572ms/step
# Epoch 4/5
# 80/80 - 46s - loss: 0.2639 - accuracy: 0.9013 - val_loss: 0.1770 - val_accuracy: 0.9350 - 46s/epoch - 573ms/step
# Epoch 5/5
# 80/80 - 46s - loss: 0.2394 - accuracy: 0.9237 - val_loss: 0.1823 - val_accuracy: 0.9300 - 46s/epoch - 572ms/step
# ########## Fold 1 accuracy: 0.9350000023841858 ##########
# ########## Fold 2 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/5
# 80/80 - 49s - loss: 0.5866 - accuracy: 0.7650 - val_loss: 0.4995 - val_accuracy: 0.7850 - 49s/epoch - 613ms/step
# Epoch 2/5
# 80/80 - 46s - loss: 0.3903 - accuracy: 0.8375 - val_loss: 0.3344 - val_accuracy: 0.8800 - 46s/epoch - 573ms/step
# Epoch 3/5
# 80/80 - 46s - loss: 0.2790 - accuracy: 0.9100 - val_loss: 0.2975 - val_accuracy: 0.8850 - 46s/epoch - 572ms/step
# Epoch 4/5
# 80/80 - 46s - loss: 0.2540 - accuracy: 0.9162 - val_loss: 0.2643 - val_accuracy: 0.9000 - 46s/epoch - 573ms/step
# Epoch 5/5
# 80/80 - 46s - loss: 0.2406 - accuracy: 0.9212 - val_loss: 0.3176 - val_accuracy: 0.8500 - 46s/epoch - 575ms/step
# ########## Fold 2 accuracy: 0.8999999761581421 ##########
# ########## Fold 3 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/5
# 80/80 - 49s - loss: 0.5084 - accuracy: 0.8062 - val_loss: 0.4912 - val_accuracy: 0.8000 - 49s/epoch - 614ms/step
# Epoch 2/5
# 80/80 - 46s - loss: 0.3377 - accuracy: 0.8650 - val_loss: 0.4281 - val_accuracy: 0.8450 - 46s/epoch - 573ms/step
# Epoch 3/5
# 80/80 - 46s - loss: 0.2787 - accuracy: 0.8888 - val_loss: 0.3641 - val_accuracy: 0.8700 - 46s/epoch - 570ms/step
# Epoch 4/5
# 80/80 - 46s - loss: 0.2401 - accuracy: 0.9062 - val_loss: 0.3560 - val_accuracy: 0.9000 - 46s/epoch - 570ms/step
# Epoch 5/5
# 80/80 - 46s - loss: 0.2152 - accuracy: 0.9162 - val_loss: 0.3756 - val_accuracy: 0.8900 - 46s/epoch - 569ms/step
# ########## Fold 3 accuracy: 0.8999999761581421 ##########
# ########## Fold 4 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/5
# 80/80 - 49s - loss: 0.5147 - accuracy: 0.7975 - val_loss: 0.4047 - val_accuracy: 0.8350 - 49s/epoch - 614ms/step
# Epoch 2/5
# 80/80 - 46s - loss: 0.3541 - accuracy: 0.8675 - val_loss: 0.3303 - val_accuracy: 0.8700 - 46s/epoch - 571ms/step
# Epoch 3/5
# 80/80 - 46s - loss: 0.2910 - accuracy: 0.8913 - val_loss: 0.3029 - val_accuracy: 0.8850 - 46s/epoch - 573ms/step
# Epoch 4/5
# 80/80 - 46s - loss: 0.2757 - accuracy: 0.9050 - val_loss: 0.3137 - val_accuracy: 0.8700 - 46s/epoch - 572ms/step
# Epoch 5/5
# 80/80 - 46s - loss: 0.2444 - accuracy: 0.9150 - val_loss: 0.3199 - val_accuracy: 0.8650 - 46s/epoch - 570ms/step
# ########## Fold 4 accuracy: 0.885 ##########

# %%
print('CV accuracy:', cv_acc)
# Out:
# CV accuracy: 0.9099999923706050
