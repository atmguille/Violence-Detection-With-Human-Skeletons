# %%
DATASET = 'movies'

# %%
# Use output of OpenPose without background
# Paths to videos for training
PATHS = [f"../datasets/{DATASET}_dataset/original_data/", f"../datasets/{DATASET}_dataset/openpose_gamma/"]

FRAME_FUNC = 'frame_diff'
# To use frame diff to weight t (current) or t+1
WEIGHT_CURRENT = True

# %%
import tensorflow as tf

# %%
# !export TF_FORCE_GPU_ALLOW_GROWTH=True
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.config.set_visible_devices(gpus[1:], 'GPU')
# Out:
# 2022-07-26 05:43:03.846439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.849315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.851428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.856882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.858847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.860896: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.861366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.863076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:03.865117: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# Set seed

# %%
SEED = 0
import random
import numpy as np
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # Load data

# %%
import numpy as np
import cv2

# %%
FRAMES_PER_VIDEO = 50 + 1
VIDEO_WIDTH, VIDEO_HEIGHT = 100, 100
N_CHANNELS = 3

def load_videos(video_IDs: list, video_frames: int = FRAMES_PER_VIDEO, video_width: int = VIDEO_WIDTH, video_height: int = VIDEO_HEIGHT,
                video_channels: int = N_CHANNELS, dtype = np.float32, normalize: bool = False) -> tuple:
    videos = np.empty((len(video_IDs), video_frames, video_height, video_width, video_channels), dtype=dtype)

    for i, video_ID in enumerate(video_IDs):
        cap = cv2.VideoCapture(video_ID)
        original_n_frames = int(cap. get(cv2. CAP_PROP_FRAME_COUNT))
        
        # Indexes of frames to be kept to comply with video_frames
        frames_idx = set(np.round(np.linspace(0, original_n_frames - 1, video_frames)).astype(int))

        frames = []
        index = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            if index in frames_idx:
                frame = cv2.resize(frame, (video_width, video_height)).astype(dtype)
                if normalize:
                    frame /= 255.0
                frames.append(frame)
            index += 1
        cap.release()

        if len(frames) != video_frames:
            # Complete with repeated frames in the begging and the end of the video
            n_repeats = (video_frames - len(frames)) / 2
            # In case n_repeats is decimal, first frames will be rounded to the nearest integer
            beggining_frames = np.tile(frames[0], [round(n_repeats + 0.001), 1, 1, 1])
            end_frames = np.tile(frames[-1], [int(n_repeats), 1, 1, 1])
            frames = np.concatenate([beggining_frames, frames, end_frames])
        
        videos[i,] = np.array(frames)
        

    return videos

# %% [markdown]
# DataGenerator class to load videos per batch, in case all videos do not fit in memory

# %%
import gc
from tensorflow.keras import backend as K

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, video_IDs: list, video_labels: list, batch_size: int, paths: list = [''], video_width: int = VIDEO_WIDTH, video_height: int = VIDEO_HEIGHT,
                video_frames: int = FRAMES_PER_VIDEO, video_channels: int = N_CHANNELS, dtype = np.float32, normalize: bool = False, shuffle: bool = True):
        self.video_IDs = video_IDs
        self.video_labels = video_labels
        self.batch_size = batch_size
        self.paths = paths
        self.video_width = video_width
        self.video_height = video_height
        self.video_frames = video_frames
        self.video_channels = video_channels
        self.dtype = dtype
        self.normalize = normalize
        self.shuffle = shuffle

    def __len__(self):
        return len(self.video_IDs) // self.batch_size

    def __getitem__(self, idx):
        batch_IDs = self.video_IDs[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_labels = self.video_labels[idx*self.batch_size:(idx+1)*self.batch_size]
        input_videos = []
        
        for index, path in enumerate(self.paths):
            batch_IDs_full_path = [path+ID for ID in batch_IDs]

            videos = load_videos(batch_IDs_full_path, self.video_frames, self.video_width, 
                                         self.video_height, self.video_channels, self.dtype, self.normalize)
            
            input_videos.append(videos)
                    
        return input_videos, batch_labels
            
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            # shuffle video_IDs and video_labels together
            temp_list = list(zip(self.video_IDs, self.video_labels))
            np.random.shuffle(temp_list)
            self.video_IDs, self.video_labels = zip(*temp_list)
        # Clear memory after epochs
        gc.collect()
        #K.clear_session()

# %% [markdown]
# ## Videos to load

# %%
import pandas as pd
folds = pd.read_csv(f'../datasets/{DATASET}_dataset/folds.csv')

def fecth_generators(fold):

    train_df = folds[folds.fold != fold]
    test_df = folds[folds.fold == fold]

    train_video_IDs = train_df.video.values
    test_video_IDs = test_df.video.values

    train_video_labels = train_df.label.values
    test_video_labels = test_df.label.values

    train_generator = DataGenerator(train_video_IDs, train_video_labels, batch_size=10, paths=PATHS)
    test_generator = DataGenerator(test_video_IDs, test_video_labels, batch_size=10, paths=PATHS)

    return train_generator, test_generator

# %% [markdown]
# # Frame functions

# %%
import tensorflow.keras.backend as K

def tf_frame_diff(video):
    return video[1:] - video[:-1]

frame_func = tf_frame_diff

# %% [markdown]
# # Load pretrained best model without optimizer

# %%
cv_acc = 0.0

for fold in range(5):
    print('#'*10, 'Fold', fold, '#'*10)

    model = tf.keras.models.load_model('models/rwf_best_model_no_optimizer.h5')
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=f'models/{DATASET}_best_model_fold{fold}.h5',
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)

    train_generator, test_generator = fecth_generators(fold)
    history = model.fit(train_generator, epochs=50, validation_data=test_generator, verbose=2, callbacks=[model_checkpoint_callback])

    fold_acc = max(history.history['val_accuracy'])
    print('#'*10, f'Fold {fold} accuracy:', fold_acc, '#'*10)
    cv_acc += fold_acc / 5
# Out:
# ########## Fold 0 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-07-26 05:43:03.968245: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-26 05:43:04.137564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.139598: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.140036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.142017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.142441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.144439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.722934: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.725012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.725465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.727489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.727929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.729933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79112 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:61:00.0, compute capability: 8.0
# 2022-07-26 05:43:04.730192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-26 05:43:04.730616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 2636 MB memory:  -> device: 2, name: NVIDIA T1000, pci bus id: 0000:41:00.0, compute capability: 7.5
# Epoch 1/50
# 2022-07-26 05:43:09.575151: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8204
# 2022-07-26 05:43:10.149482: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-07-26 05:43:10.151337: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2022-07-26 05:43:10.151370: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-07-26 05:43:10.151499: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-07-26 05:43:10.992509: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 16/16 - 21s - loss: 0.7315 - accuracy: 0.7500 - val_loss: 0.6549 - val_accuracy: 0.7000 - 21s/epoch - 1s/step
# Epoch 2/50
# 16/16 - 17s - loss: 0.3654 - accuracy: 0.8500 - val_loss: 0.4356 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 3/50
# 16/16 - 17s - loss: 0.2222 - accuracy: 0.9312 - val_loss: 0.3241 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 4/50
# 16/16 - 17s - loss: 0.1868 - accuracy: 0.9500 - val_loss: 0.3261 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 5/50
# 16/16 - 17s - loss: 0.1549 - accuracy: 0.9625 - val_loss: 0.2872 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 6/50
# 16/16 - 17s - loss: 0.1440 - accuracy: 0.9625 - val_loss: 0.2730 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 7/50
# 16/16 - 17s - loss: 0.1332 - accuracy: 0.9688 - val_loss: 0.2594 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 8/50
# 16/16 - 17s - loss: 0.1251 - accuracy: 0.9688 - val_loss: 0.2676 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 9/50
# 16/16 - 17s - loss: 0.1179 - accuracy: 0.9688 - val_loss: 0.2423 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 10/50
# 16/16 - 17s - loss: 0.1103 - accuracy: 0.9750 - val_loss: 0.2511 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 11/50
# 16/16 - 16s - loss: 0.0991 - accuracy: 0.9750 - val_loss: 0.2260 - val_accuracy: 0.9500 - 16s/epoch - 1s/step
# Epoch 12/50
# 16/16 - 17s - loss: 0.0752 - accuracy: 0.9812 - val_loss: 0.2298 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 13/50
# 16/16 - 17s - loss: 0.0782 - accuracy: 0.9688 - val_loss: 0.2217 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 14/50
# 16/16 - 17s - loss: 0.0892 - accuracy: 0.9688 - val_loss: 0.2298 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 15/50
# 16/16 - 17s - loss: 0.0526 - accuracy: 0.9875 - val_loss: 0.2052 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 16/50
# 16/16 - 17s - loss: 0.0446 - accuracy: 0.9875 - val_loss: 0.1961 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 17/50
# 16/16 - 17s - loss: 0.0481 - accuracy: 0.9812 - val_loss: 0.2114 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 18/50
# 16/16 - 17s - loss: 0.1634 - accuracy: 0.9375 - val_loss: 0.2274 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 19/50
# 16/16 - 17s - loss: 0.1163 - accuracy: 0.9500 - val_loss: 0.2280 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 20/50
# 16/16 - 17s - loss: 0.0874 - accuracy: 0.9688 - val_loss: 0.0953 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 21/50
# 16/16 - 17s - loss: 0.0688 - accuracy: 0.9625 - val_loss: 0.1275 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 22/50
# 16/16 - 17s - loss: 0.0623 - accuracy: 0.9750 - val_loss: 0.1772 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 23/50
# 16/16 - 17s - loss: 0.0525 - accuracy: 0.9812 - val_loss: 0.1548 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 24/50
# 16/16 - 17s - loss: 0.0339 - accuracy: 0.9812 - val_loss: 0.1330 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 25/50
# 16/16 - 17s - loss: 0.0260 - accuracy: 0.9875 - val_loss: 0.1392 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 26/50
# 16/16 - 17s - loss: 0.0152 - accuracy: 0.9937 - val_loss: 0.1789 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 27/50
# 16/16 - 17s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 28/50
# 16/16 - 17s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 29/50
# 16/16 - 16s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9750 - 16s/epoch - 1s/step
# Epoch 30/50
# 16/16 - 17s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 31/50
# 16/16 - 17s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 32/50
# 16/16 - 17s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 33/50
# 16/16 - 17s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 34/50
# 16/16 - 17s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 35/50
# 16/16 - 17s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 36/50
# 16/16 - 17s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 37/50
# 16/16 - 17s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 38/50
# 16/16 - 17s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 39/50
# 16/16 - 17s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 40/50
# 16/16 - 17s - loss: 9.0779e-04 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 41/50
# 16/16 - 17s - loss: 8.0010e-04 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 42/50
# 16/16 - 17s - loss: 6.7624e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 43/50
# 16/16 - 17s - loss: 6.5444e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 44/50
# 16/16 - 17s - loss: 5.9051e-04 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 45/50
# 16/16 - 17s - loss: 7.0686e-04 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 46/50
# 16/16 - 17s - loss: 5.7453e-04 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 47/50
# 16/16 - 17s - loss: 6.0083e-04 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 48/50
# 16/16 - 17s - loss: 4.5950e-04 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 49/50
# 16/16 - 17s - loss: 0.0071 - accuracy: 0.9937 - val_loss: 0.0367 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 50/50
# 16/16 - 17s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# ########## Fold 0 accuracy: 0.9750000238418579 ##########
# ########## Fold 1 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 16/16 - 21s - loss: 0.6042 - accuracy: 0.7625 - val_loss: 0.6549 - val_accuracy: 0.8250 - 21s/epoch - 1s/step
# Epoch 2/50
# 16/16 - 16s - loss: 0.2648 - accuracy: 0.9250 - val_loss: 0.5717 - val_accuracy: 0.8500 - 16s/epoch - 1s/step
# Epoch 3/50
# 16/16 - 17s - loss: 0.1878 - accuracy: 0.9500 - val_loss: 0.5441 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 4/50
# 16/16 - 17s - loss: 0.1392 - accuracy: 0.9625 - val_loss: 0.5378 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 5/50
# 16/16 - 17s - loss: 0.1110 - accuracy: 0.9812 - val_loss: 0.5594 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 6/50
# 16/16 - 17s - loss: 0.1031 - accuracy: 0.9750 - val_loss: 0.5294 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 7/50
# 16/16 - 17s - loss: 0.0948 - accuracy: 0.9812 - val_loss: 0.5220 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 8/50
# 16/16 - 17s - loss: 0.0872 - accuracy: 0.9812 - val_loss: 0.4620 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 9/50
# 16/16 - 17s - loss: 0.0624 - accuracy: 0.9875 - val_loss: 0.4899 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 10/50
# 16/16 - 17s - loss: 0.0691 - accuracy: 0.9812 - val_loss: 0.5586 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 11/50
# 16/16 - 17s - loss: 0.0718 - accuracy: 0.9812 - val_loss: 0.5183 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 12/50
# 16/16 - 17s - loss: 0.0546 - accuracy: 0.9937 - val_loss: 0.4913 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 13/50
# 16/16 - 17s - loss: 0.0450 - accuracy: 0.9937 - val_loss: 0.5029 - val_accuracy: 0.8750 - 17s/epoch - 1s/step
# Epoch 14/50
# 16/16 - 17s - loss: 0.0443 - accuracy: 0.9875 - val_loss: 0.4825 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 15/50
# 16/16 - 17s - loss: 0.0333 - accuracy: 0.9937 - val_loss: 0.5095 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 16/50
# 16/16 - 17s - loss: 0.0322 - accuracy: 0.9937 - val_loss: 0.5216 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 17/50
# 16/16 - 17s - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.4761 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 18/50
# 16/16 - 17s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4960 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 19/50
# 16/16 - 17s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 20/50
# 16/16 - 17s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5524 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 21/50
# 16/16 - 17s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.5575 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 22/50
# 16/16 - 17s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5776 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 23/50
# 16/16 - 17s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 24/50
# 16/16 - 17s - loss: 0.0070 - accuracy: 0.9937 - val_loss: 0.6152 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 25/50
# 16/16 - 17s - loss: 0.0118 - accuracy: 0.9937 - val_loss: 0.5740 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 26/50
# 16/16 - 17s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.6693 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 27/50
# 16/16 - 17s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7270 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 28/50
# 16/16 - 17s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6699 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 29/50
# 16/16 - 17s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6753 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 30/50
# 16/16 - 17s - loss: 9.9686e-04 - accuracy: 1.0000 - val_loss: 0.7302 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 31/50
# 16/16 - 17s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7478 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 32/50
# 16/16 - 17s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7447 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 33/50
# 16/16 - 17s - loss: 6.5452e-04 - accuracy: 1.0000 - val_loss: 0.7600 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 34/50
# 16/16 - 17s - loss: 5.0807e-04 - accuracy: 1.0000 - val_loss: 0.7845 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 35/50
# 16/16 - 17s - loss: 4.7808e-04 - accuracy: 1.0000 - val_loss: 0.7922 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 36/50
# 16/16 - 17s - loss: 4.3895e-04 - accuracy: 1.0000 - val_loss: 0.8057 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 37/50
# 16/16 - 17s - loss: 3.7121e-04 - accuracy: 1.0000 - val_loss: 0.8209 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 38/50
# 16/16 - 17s - loss: 3.2180e-04 - accuracy: 1.0000 - val_loss: 0.8305 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 39/50
# 16/16 - 17s - loss: 4.1315e-04 - accuracy: 1.0000 - val_loss: 0.8336 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 40/50
# 16/16 - 17s - loss: 3.0832e-04 - accuracy: 1.0000 - val_loss: 0.8455 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 41/50
# 16/16 - 17s - loss: 2.6291e-04 - accuracy: 1.0000 - val_loss: 0.8623 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 42/50
# 16/16 - 17s - loss: 3.6995e-04 - accuracy: 1.0000 - val_loss: 0.8585 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 43/50
# 16/16 - 17s - loss: 2.8124e-04 - accuracy: 1.0000 - val_loss: 0.8775 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 44/50
# 16/16 - 17s - loss: 2.5305e-04 - accuracy: 1.0000 - val_loss: 0.8902 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 45/50
# 16/16 - 17s - loss: 6.7569e-04 - accuracy: 1.0000 - val_loss: 0.8998 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 46/50
# 16/16 - 17s - loss: 3.7057e-04 - accuracy: 1.0000 - val_loss: 0.9260 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 47/50
# 16/16 - 17s - loss: 1.6431e-04 - accuracy: 1.0000 - val_loss: 0.9649 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 48/50
# 16/16 - 17s - loss: 1.9180e-04 - accuracy: 1.0000 - val_loss: 0.9835 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 49/50
# 16/16 - 17s - loss: 1.4715e-04 - accuracy: 1.0000 - val_loss: 0.9944 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 50/50
# 16/16 - 17s - loss: 1.4466e-04 - accuracy: 1.0000 - val_loss: 1.0019 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# ########## Fold 1 accuracy: 0.949999988079071 ##########
# ########## Fold 2 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 16/16 - 21s - loss: 0.5441 - accuracy: 0.7812 - val_loss: 0.4667 - val_accuracy: 0.7750 - 21s/epoch - 1s/step
# Epoch 2/50
# 16/16 - 17s - loss: 0.3175 - accuracy: 0.9187 - val_loss: 0.2825 - val_accuracy: 0.9000 - 17s/epoch - 1s/step
# Epoch 3/50
# 16/16 - 17s - loss: 0.2512 - accuracy: 0.9187 - val_loss: 0.1861 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 4/50
# 16/16 - 17s - loss: 0.1986 - accuracy: 0.9375 - val_loss: 0.1734 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 5/50
# 16/16 - 17s - loss: 0.1882 - accuracy: 0.9438 - val_loss: 0.1662 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 6/50
# 16/16 - 17s - loss: 0.1925 - accuracy: 0.9438 - val_loss: 0.1162 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 7/50
# 16/16 - 17s - loss: 0.1335 - accuracy: 0.9688 - val_loss: 0.1525 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 8/50
# 16/16 - 17s - loss: 0.1351 - accuracy: 0.9688 - val_loss: 0.1134 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 9/50
# 16/16 - 17s - loss: 0.1371 - accuracy: 0.9688 - val_loss: 0.1088 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 10/50
# 16/16 - 17s - loss: 0.0955 - accuracy: 0.9812 - val_loss: 0.1118 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 11/50
# 16/16 - 17s - loss: 0.0886 - accuracy: 0.9812 - val_loss: 0.0935 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 12/50
# 16/16 - 17s - loss: 0.1414 - accuracy: 0.9438 - val_loss: 0.0978 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 13/50
# 16/16 - 17s - loss: 0.1274 - accuracy: 0.9563 - val_loss: 0.1056 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 14/50
# 16/16 - 17s - loss: 0.0857 - accuracy: 0.9750 - val_loss: 0.1094 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 15/50
# 16/16 - 17s - loss: 0.0674 - accuracy: 0.9812 - val_loss: 0.1303 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 16/50
# 16/16 - 17s - loss: 0.0726 - accuracy: 0.9812 - val_loss: 0.1574 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 17/50
# 16/16 - 17s - loss: 0.0636 - accuracy: 0.9812 - val_loss: 0.1167 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 18/50
# 16/16 - 17s - loss: 0.0533 - accuracy: 0.9875 - val_loss: 0.1290 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 19/50
# 16/16 - 17s - loss: 0.0494 - accuracy: 0.9875 - val_loss: 0.1337 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 20/50
# 16/16 - 17s - loss: 0.0479 - accuracy: 0.9875 - val_loss: 0.1610 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 21/50
# 16/16 - 17s - loss: 0.0454 - accuracy: 0.9875 - val_loss: 0.0689 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 22/50
# 16/16 - 17s - loss: 0.0370 - accuracy: 0.9875 - val_loss: 0.0726 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 23/50
# 16/16 - 17s - loss: 0.0332 - accuracy: 0.9875 - val_loss: 0.0684 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 24/50
# 16/16 - 17s - loss: 0.0480 - accuracy: 0.9750 - val_loss: 0.0753 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 25/50
# 16/16 - 17s - loss: 0.0350 - accuracy: 0.9812 - val_loss: 0.0652 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 26/50
# 16/16 - 17s - loss: 0.0444 - accuracy: 0.9812 - val_loss: 0.0625 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 27/50
# 16/16 - 17s - loss: 0.0345 - accuracy: 0.9812 - val_loss: 0.0753 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 28/50
# 16/16 - 17s - loss: 0.0306 - accuracy: 0.9875 - val_loss: 0.0841 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 29/50
# 16/16 - 17s - loss: 0.0274 - accuracy: 0.9875 - val_loss: 0.0519 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 30/50
# 16/16 - 17s - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.1029 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 31/50
# 16/16 - 17s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 32/50
# 16/16 - 17s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 33/50
# 16/16 - 17s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 34/50
# 16/16 - 17s - loss: 0.0144 - accuracy: 0.9937 - val_loss: 0.0648 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 35/50
# 16/16 - 17s - loss: 0.0336 - accuracy: 0.9875 - val_loss: 0.0897 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 36/50
# 16/16 - 17s - loss: 0.0153 - accuracy: 0.9937 - val_loss: 0.1040 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 37/50
# 16/16 - 17s - loss: 0.0412 - accuracy: 0.9875 - val_loss: 0.0469 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 38/50
# 16/16 - 17s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 39/50
# 16/16 - 17s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 40/50
# 16/16 - 17s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 41/50
# 16/16 - 17s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 42/50
# 16/16 - 17s - loss: 8.1388e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 43/50
# 16/16 - 17s - loss: 6.7706e-04 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 44/50
# 16/16 - 17s - loss: 5.7762e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 45/50
# 16/16 - 17s - loss: 6.8397e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 46/50
# 16/16 - 17s - loss: 4.7842e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 47/50
# 16/16 - 17s - loss: 8.0262e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 48/50
# 16/16 - 17s - loss: 3.8511e-04 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 49/50
# 16/16 - 17s - loss: 4.0502e-04 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 50/50
# 16/16 - 17s - loss: 4.6478e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# ########## Fold 2 accuracy: 1.0 ##########
# ########## Fold 3 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 16/16 - 21s - loss: 0.9431 - accuracy: 0.6875 - val_loss: 0.3479 - val_accuracy: 0.8500 - 21s/epoch - 1s/step
# Epoch 2/50
# 16/16 - 17s - loss: 0.4170 - accuracy: 0.8438 - val_loss: 0.1933 - val_accuracy: 0.9250 - 17s/epoch - 1s/step
# Epoch 3/50
# 16/16 - 17s - loss: 0.2848 - accuracy: 0.9000 - val_loss: 0.0954 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 4/50
# 16/16 - 17s - loss: 0.2254 - accuracy: 0.9375 - val_loss: 0.0679 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 5/50
# 16/16 - 17s - loss: 0.2056 - accuracy: 0.9312 - val_loss: 0.0626 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 6/50
# 16/16 - 17s - loss: 0.1815 - accuracy: 0.9438 - val_loss: 0.0774 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 7/50
# 16/16 - 17s - loss: 0.1663 - accuracy: 0.9625 - val_loss: 0.0501 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 8/50
# 16/16 - 17s - loss: 0.1559 - accuracy: 0.9688 - val_loss: 0.0617 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 9/50
# 16/16 - 17s - loss: 0.1743 - accuracy: 0.9500 - val_loss: 0.0736 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 10/50
# 16/16 - 17s - loss: 0.1384 - accuracy: 0.9625 - val_loss: 0.0650 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 11/50
# 16/16 - 17s - loss: 0.1263 - accuracy: 0.9688 - val_loss: 0.0522 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 12/50
# 16/16 - 17s - loss: 0.1295 - accuracy: 0.9563 - val_loss: 0.0461 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 13/50
# 16/16 - 17s - loss: 0.1094 - accuracy: 0.9688 - val_loss: 0.0587 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 14/50
# 16/16 - 17s - loss: 0.1175 - accuracy: 0.9500 - val_loss: 0.0471 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 15/50
# 16/16 - 17s - loss: 0.0983 - accuracy: 0.9750 - val_loss: 0.0311 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 16/50
# 16/16 - 17s - loss: 0.1029 - accuracy: 0.9563 - val_loss: 0.0411 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 17/50
# 16/16 - 17s - loss: 0.0801 - accuracy: 0.9750 - val_loss: 0.0286 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 18/50
# 16/16 - 17s - loss: 0.0734 - accuracy: 0.9750 - val_loss: 0.0318 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 19/50
# 16/16 - 17s - loss: 0.0627 - accuracy: 0.9812 - val_loss: 0.0266 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 20/50
# 16/16 - 17s - loss: 0.0516 - accuracy: 0.9812 - val_loss: 0.0331 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 21/50
# 16/16 - 17s - loss: 0.0444 - accuracy: 0.9812 - val_loss: 0.0272 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 22/50
# 16/16 - 17s - loss: 0.0398 - accuracy: 0.9812 - val_loss: 0.0316 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 23/50
# 16/16 - 17s - loss: 0.0392 - accuracy: 0.9812 - val_loss: 0.0335 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 24/50
# 16/16 - 17s - loss: 0.0305 - accuracy: 0.9812 - val_loss: 0.0292 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 25/50
# 16/16 - 17s - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0530 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 26/50
# 16/16 - 17s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 27/50
# 16/16 - 17s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 28/50
# 16/16 - 17s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 29/50
# 16/16 - 17s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 30/50
# 16/16 - 17s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 31/50
# 16/16 - 17s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 32/50
# 16/16 - 17s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 33/50
# 16/16 - 17s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 34/50
# 16/16 - 17s - loss: 8.3829e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 35/50
# 16/16 - 17s - loss: 7.5683e-04 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 36/50
# 16/16 - 17s - loss: 6.6722e-04 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 37/50
# 16/16 - 17s - loss: 5.5435e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 38/50
# 16/16 - 17s - loss: 5.0045e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 39/50
# 16/16 - 17s - loss: 4.9656e-04 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 40/50
# 16/16 - 17s - loss: 4.1749e-04 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 41/50
# 16/16 - 17s - loss: 9.7108e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 42/50
# 16/16 - 17s - loss: 3.8190e-04 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 43/50
# 16/16 - 17s - loss: 4.5633e-04 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 44/50
# 16/16 - 17s - loss: 2.9516e-04 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 45/50
# 16/16 - 17s - loss: 2.8217e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 46/50
# 16/16 - 17s - loss: 3.0406e-04 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 47/50
# 16/16 - 17s - loss: 2.4823e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 48/50
# 16/16 - 17s - loss: 2.0686e-04 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 49/50
# 16/16 - 17s - loss: 2.3268e-04 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 50/50
# 16/16 - 17s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# ########## Fold 3 accuracy: 1.0 ##########
# ########## Fold 4 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 16/16 - 21s - loss: 0.6655 - accuracy: 0.7812 - val_loss: 0.4418 - val_accuracy: 0.7750 - 21s/epoch - 1s/step
# Epoch 2/50
# 16/16 - 17s - loss: 0.2514 - accuracy: 0.9312 - val_loss: 0.1658 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 4/50
# 16/16 - 17s - loss: 0.1916 - accuracy: 0.9438 - val_loss: 0.1531 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 5/50
# 16/16 - 17s - loss: 0.1692 - accuracy: 0.9688 - val_loss: 0.1366 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 6/50
# 16/16 - 17s - loss: 0.1517 - accuracy: 0.9625 - val_loss: 0.1377 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 7/50
# 16/16 - 17s - loss: 0.1296 - accuracy: 0.9688 - val_loss: 0.1315 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 8/50
# 16/16 - 17s - loss: 0.1258 - accuracy: 0.9688 - val_loss: 0.1250 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 9/50
# 16/16 - 17s - loss: 0.1157 - accuracy: 0.9688 - val_loss: 0.1173 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 10/50
# 16/16 - 17s - loss: 0.1020 - accuracy: 0.9750 - val_loss: 0.1139 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 11/50
# 16/16 - 17s - loss: 0.0846 - accuracy: 0.9750 - val_loss: 0.1241 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 12/50
# 16/16 - 17s - loss: 0.1023 - accuracy: 0.9688 - val_loss: 0.1125 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 13/50
# 16/16 - 17s - loss: 0.0730 - accuracy: 0.9750 - val_loss: 0.1207 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 14/50
# 16/16 - 17s - loss: 0.0702 - accuracy: 0.9812 - val_loss: 0.0869 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 15/50
# 16/16 - 17s - loss: 0.0621 - accuracy: 0.9812 - val_loss: 0.1235 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 16/50
# 16/16 - 17s - loss: 0.0660 - accuracy: 0.9812 - val_loss: 0.0796 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 17/50
# 16/16 - 17s - loss: 0.0610 - accuracy: 0.9812 - val_loss: 0.0747 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 18/50
# 16/16 - 17s - loss: 0.0538 - accuracy: 0.9812 - val_loss: 0.0678 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 19/50
# 16/16 - 17s - loss: 0.0444 - accuracy: 0.9812 - val_loss: 0.1101 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 20/50
# 16/16 - 17s - loss: 0.0552 - accuracy: 0.9812 - val_loss: 0.0393 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 21/50
# 16/16 - 17s - loss: 0.0391 - accuracy: 0.9812 - val_loss: 0.0328 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 22/50
# 16/16 - 17s - loss: 0.0397 - accuracy: 0.9812 - val_loss: 0.0305 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 23/50
# 16/16 - 17s - loss: 0.0507 - accuracy: 0.9750 - val_loss: 0.0930 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 24/50
# 16/16 - 17s - loss: 0.0450 - accuracy: 0.9812 - val_loss: 0.0937 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 25/50
# 16/16 - 17s - loss: 0.0350 - accuracy: 0.9812 - val_loss: 0.0957 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 26/50
# 16/16 - 17s - loss: 0.0381 - accuracy: 0.9812 - val_loss: 0.0738 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 27/50
# 16/16 - 17s - loss: 0.0369 - accuracy: 0.9812 - val_loss: 0.0536 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 28/50
# 16/16 - 17s - loss: 0.0345 - accuracy: 0.9812 - val_loss: 0.0503 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 29/50
# 16/16 - 17s - loss: 0.0289 - accuracy: 0.9812 - val_loss: 0.0615 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 30/50
# 16/16 - 17s - loss: 0.0389 - accuracy: 0.9750 - val_loss: 0.0556 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 31/50
# 16/16 - 17s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 32/50
# 16/16 - 17s - loss: 0.0273 - accuracy: 0.9812 - val_loss: 0.0342 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 33/50
# 16/16 - 17s - loss: 0.0257 - accuracy: 0.9812 - val_loss: 0.0252 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 34/50
# 16/16 - 17s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 35/50
# 16/16 - 17s - loss: 0.0244 - accuracy: 0.9937 - val_loss: 0.0861 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 36/50
# 16/16 - 17s - loss: 0.0296 - accuracy: 0.9937 - val_loss: 0.0260 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 37/50
# 16/16 - 17s - loss: 0.0257 - accuracy: 0.9937 - val_loss: 0.0440 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 38/50
# 16/16 - 17s - loss: 0.0363 - accuracy: 0.9875 - val_loss: 0.0221 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 39/50
# 16/16 - 17s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 40/50
# 16/16 - 17s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 41/50
# 16/16 - 17s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 42/50
# 16/16 - 17s - loss: 8.0294e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 43/50
# 16/16 - 17s - loss: 6.8305e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 44/50
# 16/16 - 17s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9500 - 17s/epoch - 1s/step
# Epoch 45/50
# 16/16 - 17s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 46/50
# 16/16 - 17s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# Epoch 47/50
# 16/16 - 17s - loss: 5.8959e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 48/50
# 16/16 - 17s - loss: 5.4406e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 49/50
# 16/16 - 17s - loss: 4.8479e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9750 - 17s/epoch - 1s/step
# Epoch 50/50
# 16/16 - 17s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000 - 17s/epoch - 1s/step
# ########## Fold 4 accuracy: 1.0 ##########

# %%
print('CV accuracy:', cv_acc)
# Out:
# CV accuracy: 0.9850000023841858
