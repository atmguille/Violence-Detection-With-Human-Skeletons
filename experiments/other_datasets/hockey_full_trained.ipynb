# %%
DATASET = 'hockey'

# %%
# Use output of OpenPose without background
# Paths to videos for training
PATHS = [f"../datasets/{DATASET}_dataset/original_data/", f"../datasets/{DATASET}_dataset/openpose_gamma/"]

FRAME_FUNC = 'frame_diff'
# To use frame diff to weight t (current) or t+1
WEIGHT_CURRENT = True

# %%
import tensorflow as tf

# %%
# !export TF_FORCE_GPU_ALLOW_GROWTH=True
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.config.set_visible_devices(gpus[0:1], 'GPU')
# Out:
# 2022-07-23 10:27:16.099361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.101101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.102130: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.107692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.109442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.110470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.110921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.112629: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.113678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# Set seed

# %%
SEED = 0
import random
import numpy as np
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # Load data

# %%
import numpy as np
import cv2

# %%
FRAMES_PER_VIDEO = 50 + 1
VIDEO_WIDTH, VIDEO_HEIGHT = 100, 100
N_CHANNELS = 3

def load_videos(video_IDs: list, video_frames: int = FRAMES_PER_VIDEO, video_width: int = VIDEO_WIDTH, video_height: int = VIDEO_HEIGHT,
                video_channels: int = N_CHANNELS, dtype = np.float32, normalize: bool = False) -> tuple:
    videos = np.empty((len(video_IDs), video_frames, video_height, video_width, video_channels), dtype=dtype)

    for i, video_ID in enumerate(video_IDs):
        cap = cv2.VideoCapture(video_ID)
        original_n_frames = int(cap. get(cv2. CAP_PROP_FRAME_COUNT))
        
        # Indexes of frames to be kept to comply with video_frames
        frames_idx = set(np.round(np.linspace(0, original_n_frames - 1, video_frames)).astype(int))

        frames = []
        index = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            if index in frames_idx:
                frame = cv2.resize(frame, (video_width, video_height)).astype(dtype)
                if normalize:
                    frame /= 255.0
                frames.append(frame)
            index += 1
        cap.release()

        if len(frames) != video_frames:
            # Complete with repeated frames in the begging and the end of the video
            n_repeats = (video_frames - len(frames)) / 2
            # In case n_repeats is decimal, first frames will be rounded to the nearest integer
            beggining_frames = np.tile(frames[0], [round(n_repeats + 0.001), 1, 1, 1])
            end_frames = np.tile(frames[-1], [int(n_repeats), 1, 1, 1])
            frames = np.concatenate([beggining_frames, frames, end_frames])
        
        videos[i,] = np.array(frames)
        

    return videos

# %% [markdown]
# DataGenerator class to load videos per batch, in case all videos do not fit in memory

# %%
import gc
from tensorflow.keras import backend as K

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, video_IDs: list, video_labels: list, batch_size: int, paths: list = [''], video_width: int = VIDEO_WIDTH, video_height: int = VIDEO_HEIGHT,
                video_frames: int = FRAMES_PER_VIDEO, video_channels: int = N_CHANNELS, dtype = np.float32, normalize: bool = False, shuffle: bool = True):
        self.video_IDs = video_IDs
        self.video_labels = video_labels
        self.batch_size = batch_size
        self.paths = paths
        self.video_width = video_width
        self.video_height = video_height
        self.video_frames = video_frames
        self.video_channels = video_channels
        self.dtype = dtype
        self.normalize = normalize
        self.shuffle = shuffle

    def __len__(self):
        return len(self.video_IDs) // self.batch_size

    def __getitem__(self, idx):
        batch_IDs = self.video_IDs[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_labels = self.video_labels[idx*self.batch_size:(idx+1)*self.batch_size]
        input_videos = []
        
        for index, path in enumerate(self.paths):
            batch_IDs_full_path = [path+ID for ID in batch_IDs]

            videos = load_videos(batch_IDs_full_path, self.video_frames, self.video_width, 
                                         self.video_height, self.video_channels, self.dtype, self.normalize)
            
            input_videos.append(videos)
                    
        return input_videos, batch_labels
            
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            # shuffle video_IDs and video_labels together
            temp_list = list(zip(self.video_IDs, self.video_labels))
            np.random.shuffle(temp_list)
            self.video_IDs, self.video_labels = zip(*temp_list)
        # Clear memory after epochs
        gc.collect()
        #K.clear_session()

# %% [markdown]
# ## Videos to load

# %%
import pandas as pd
folds = pd.read_csv(f'../datasets/{DATASET}_dataset/folds.csv')

def fecth_generators(fold):

    train_df = folds[folds.fold != fold]
    test_df = folds[folds.fold == fold]

    train_video_IDs = train_df.video.values
    test_video_IDs = test_df.video.values

    train_video_labels = train_df.label.values
    test_video_labels = test_df.label.values

    train_generator = DataGenerator(train_video_IDs, train_video_labels, batch_size=10, paths=PATHS)
    test_generator = DataGenerator(test_video_IDs, test_video_labels, batch_size=10, paths=PATHS)

    return train_generator, test_generator

# %% [markdown]
# # Frame functions

# %%
import tensorflow.keras.backend as K

def tf_frame_diff(video):
    return video[1:] - video[:-1]

frame_func = tf_frame_diff

# %% [markdown]
# # Load pretrained best model without optimizer

# %%
cv_acc = 0.0

for fold in range(5):
    print('#'*10, 'Fold', fold, '#'*10)

    model = tf.keras.models.load_model('models/rwf_best_model_no_optimizer.h5')
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=f'models/{DATASET}_best_model_fold{fold}.h5',
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)

    train_generator, test_generator = fecth_generators(fold)
    history = model.fit(train_generator, epochs=50, validation_data=test_generator, verbose=2, callbacks=[model_checkpoint_callback])

    fold_acc = max(history.history['val_accuracy'])
    print('#'*10, f'Fold {fold} accuracy:', fold_acc, '#'*10)
    cv_acc += fold_acc / 5
# Out:
# ########## Fold 0 ##########
# Epoch 1/50
# 2022-07-23 10:27:16.211968: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-23 10:27:16.214760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.216515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.218192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.932930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.934664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.936358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 10:27:16.938074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 61037 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:01:00.0, compute capability: 8.0
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-07-23 10:27:21.670614: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8204
# 2022-07-23 10:27:22.336579: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-07-23 10:27:22.338582: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2022-07-23 10:27:22.338616: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-07-23 10:27:22.338753: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-07-23 10:27:23.341759: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 80/80 - 100s - loss: 0.6803 - accuracy: 0.6363 - val_loss: 0.6366 - val_accuracy: 0.6500 - 100s/epoch - 1s/step
# Epoch 2/50
# 80/80 - 102s - loss: 0.5016 - accuracy: 0.7788 - val_loss: 0.4439 - val_accuracy: 0.8050 - 102s/epoch - 1s/step
# Epoch 3/50
# 80/80 - 101s - loss: 0.4045 - accuracy: 0.8313 - val_loss: 0.4297 - val_accuracy: 0.8300 - 101s/epoch - 1s/step
# Epoch 4/50
# 80/80 - 101s - loss: 0.3660 - accuracy: 0.8500 - val_loss: 0.3632 - val_accuracy: 0.8650 - 101s/epoch - 1s/step
# Epoch 5/50
# 80/80 - 102s - loss: 0.3431 - accuracy: 0.8737 - val_loss: 0.3758 - val_accuracy: 0.8550 - 102s/epoch - 1s/step
# Epoch 6/50
# 80/80 - 101s - loss: 0.3185 - accuracy: 0.8650 - val_loss: 0.3387 - val_accuracy: 0.8700 - 101s/epoch - 1s/step
# Epoch 7/50
# 80/80 - 102s - loss: 0.3083 - accuracy: 0.8825 - val_loss: 0.2932 - val_accuracy: 0.9000 - 102s/epoch - 1s/step
# Epoch 8/50
# 80/80 - 103s - loss: 0.3128 - accuracy: 0.8900 - val_loss: 0.3422 - val_accuracy: 0.8750 - 103s/epoch - 1s/step
# Epoch 9/50
# 80/80 - 101s - loss: 0.2935 - accuracy: 0.8913 - val_loss: 0.2796 - val_accuracy: 0.9000 - 101s/epoch - 1s/step
# Epoch 10/50
# 80/80 - 103s - loss: 0.2697 - accuracy: 0.9000 - val_loss: 0.2654 - val_accuracy: 0.9150 - 103s/epoch - 1s/step
# Epoch 11/50
# 80/80 - 102s - loss: 0.2728 - accuracy: 0.8975 - val_loss: 0.2696 - val_accuracy: 0.9100 - 102s/epoch - 1s/step
# Epoch 12/50
# 80/80 - 101s - loss: 0.2553 - accuracy: 0.9025 - val_loss: 0.2890 - val_accuracy: 0.8950 - 101s/epoch - 1s/step
# Epoch 13/50
# 80/80 - 102s - loss: 0.2538 - accuracy: 0.9125 - val_loss: 0.2725 - val_accuracy: 0.9050 - 102s/epoch - 1s/step
# Epoch 14/50
# 80/80 - 102s - loss: 0.2188 - accuracy: 0.9275 - val_loss: 0.2487 - val_accuracy: 0.9150 - 102s/epoch - 1s/step
# Epoch 15/50
# 80/80 - 100s - loss: 0.2102 - accuracy: 0.9237 - val_loss: 0.2432 - val_accuracy: 0.9250 - 100s/epoch - 1s/step
# Epoch 16/50
# 80/80 - 103s - loss: 0.2025 - accuracy: 0.9225 - val_loss: 0.2143 - val_accuracy: 0.9300 - 103s/epoch - 1s/step
# Epoch 17/50
# 80/80 - 103s - loss: 0.1873 - accuracy: 0.9325 - val_loss: 0.2218 - val_accuracy: 0.9300 - 103s/epoch - 1s/step
# Epoch 18/50
# 80/80 - 102s - loss: 0.2026 - accuracy: 0.9225 - val_loss: 0.2242 - val_accuracy: 0.9350 - 102s/epoch - 1s/step
# Epoch 19/50
# 80/80 - 101s - loss: 0.1837 - accuracy: 0.9375 - val_loss: 0.2574 - val_accuracy: 0.9200 - 101s/epoch - 1s/step
# Epoch 20/50
# 80/80 - 102s - loss: 0.1944 - accuracy: 0.9250 - val_loss: 0.2040 - val_accuracy: 0.9250 - 102s/epoch - 1s/step
# Epoch 21/50
# 80/80 - 103s - loss: 0.1816 - accuracy: 0.9362 - val_loss: 0.2639 - val_accuracy: 0.9050 - 103s/epoch - 1s/step
# Epoch 22/50
# 80/80 - 100s - loss: 0.1640 - accuracy: 0.9425 - val_loss: 0.2946 - val_accuracy: 0.8850 - 100s/epoch - 1s/step
# Epoch 23/50
# 80/80 - 102s - loss: 0.1831 - accuracy: 0.9337 - val_loss: 0.3350 - val_accuracy: 0.8750 - 102s/epoch - 1s/step
# Epoch 24/50
# 80/80 - 102s - loss: 0.2028 - accuracy: 0.9200 - val_loss: 0.2355 - val_accuracy: 0.9100 - 102s/epoch - 1s/step
# Epoch 25/50
# 80/80 - 103s - loss: 0.1763 - accuracy: 0.9337 - val_loss: 0.2065 - val_accuracy: 0.9400 - 103s/epoch - 1s/step
# Epoch 26/50
# 80/80 - 99s - loss: 0.1642 - accuracy: 0.9388 - val_loss: 0.3703 - val_accuracy: 0.8700 - 99s/epoch - 1s/step
# Epoch 27/50
# 80/80 - 103s - loss: 0.1665 - accuracy: 0.9425 - val_loss: 0.2190 - val_accuracy: 0.9350 - 103s/epoch - 1s/step
# Epoch 28/50
# 80/80 - 103s - loss: 0.1508 - accuracy: 0.9413 - val_loss: 0.2234 - val_accuracy: 0.9300 - 103s/epoch - 1s/step
# Epoch 29/50
# 80/80 - 101s - loss: 0.1486 - accuracy: 0.9500 - val_loss: 0.2409 - val_accuracy: 0.9150 - 101s/epoch - 1s/step
# Epoch 30/50
# 80/80 - 103s - loss: 0.1417 - accuracy: 0.9563 - val_loss: 0.2021 - val_accuracy: 0.9450 - 103s/epoch - 1s/step
# Epoch 31/50
# 80/80 - 103s - loss: 0.1207 - accuracy: 0.9638 - val_loss: 0.2304 - val_accuracy: 0.9250 - 103s/epoch - 1s/step
# Epoch 32/50
# 80/80 - 102s - loss: 0.1863 - accuracy: 0.9312 - val_loss: 0.2110 - val_accuracy: 0.9250 - 102s/epoch - 1s/step
# Epoch 33/50
# 80/80 - 102s - loss: 0.1418 - accuracy: 0.9475 - val_loss: 0.3191 - val_accuracy: 0.9050 - 102s/epoch - 1s/step
# Epoch 34/50
# 80/80 - 103s - loss: 0.1570 - accuracy: 0.9488 - val_loss: 0.2625 - val_accuracy: 0.9050 - 103s/epoch - 1s/step
# Epoch 35/50
# 80/80 - 102s - loss: 0.1446 - accuracy: 0.9563 - val_loss: 0.3271 - val_accuracy: 0.8850 - 102s/epoch - 1s/step
# Epoch 36/50
# 80/80 - 103s - loss: 0.1570 - accuracy: 0.9425 - val_loss: 0.2228 - val_accuracy: 0.9250 - 103s/epoch - 1s/step
# Epoch 37/50
# 80/80 - 103s - loss: 0.1274 - accuracy: 0.9600 - val_loss: 0.2505 - val_accuracy: 0.9100 - 103s/epoch - 1s/step
# Epoch 38/50
# 80/80 - 102s - loss: 0.1316 - accuracy: 0.9525 - val_loss: 0.2357 - val_accuracy: 0.9350 - 102s/epoch - 1s/step
# Epoch 39/50
# 80/80 - 103s - loss: 0.1162 - accuracy: 0.9600 - val_loss: 0.2340 - val_accuracy: 0.9300 - 103s/epoch - 1s/step
# Epoch 40/50
# 80/80 - 103s - loss: 0.1139 - accuracy: 0.9663 - val_loss: 0.2341 - val_accuracy: 0.9350 - 103s/epoch - 1s/step
# Epoch 41/50
# 80/80 - 103s - loss: 0.1340 - accuracy: 0.9488 - val_loss: 0.2937 - val_accuracy: 0.8950 - 103s/epoch - 1s/step
# Epoch 42/50
# 80/80 - 103s - loss: 0.2148 - accuracy: 0.9237 - val_loss: 0.2333 - val_accuracy: 0.9300 - 103s/epoch - 1s/step
# Epoch 43/50
# 80/80 - 103s - loss: 0.1948 - accuracy: 0.9287 - val_loss: 0.2603 - val_accuracy: 0.9100 - 103s/epoch - 1s/step
# Epoch 44/50
# 80/80 - 103s - loss: 0.1749 - accuracy: 0.9388 - val_loss: 0.1971 - val_accuracy: 0.9300 - 103s/epoch - 1s/step
# Epoch 45/50
# 80/80 - 102s - loss: 0.1442 - accuracy: 0.9438 - val_loss: 0.2057 - val_accuracy: 0.9400 - 102s/epoch - 1s/step
# Epoch 46/50
# 80/80 - 103s - loss: 0.1295 - accuracy: 0.9613 - val_loss: 0.2072 - val_accuracy: 0.9400 - 103s/epoch - 1s/step
# Epoch 47/50
# 80/80 - 103s - loss: 0.1710 - accuracy: 0.9450 - val_loss: 0.3167 - val_accuracy: 0.9100 - 103s/epoch - 1s/step
# Epoch 48/50
# 80/80 - 101s - loss: 0.1418 - accuracy: 0.9575 - val_loss: 0.1981 - val_accuracy: 0.9350 - 101s/epoch - 1s/step
# Epoch 49/50
# 80/80 - 103s - loss: 0.1194 - accuracy: 0.9600 - val_loss: 0.1933 - val_accuracy: 0.9450 - 103s/epoch - 1s/step
# Epoch 50/50
# 80/80 - 103s - loss: 0.1170 - accuracy: 0.9625 - val_loss: 0.2087 - val_accuracy: 0.9400 - 103s/epoch - 1s/step
# ########## Fold 0 accuracy: 0.9449999928474426 ##########
# ########## Fold 1 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 80/80 - 101s - loss: 0.6968 - accuracy: 0.4425 - val_loss: 0.6912 - val_accuracy: 0.5000 - 101s/epoch - 1s/step
# Epoch 2/50
# 80/80 - 103s - loss: 0.6854 - accuracy: 0.5713 - val_loss: 0.6518 - val_accuracy: 0.6550 - 103s/epoch - 1s/step
# Epoch 3/50
# 80/80 - 102s - loss: 0.5468 - accuracy: 0.7550 - val_loss: 0.3171 - val_accuracy: 0.8750 - 102s/epoch - 1s/step
# Epoch 4/50
# 80/80 - 102s - loss: 0.4374 - accuracy: 0.8238 - val_loss: 0.2979 - val_accuracy: 0.9200 - 102s/epoch - 1s/step
# Epoch 5/50
# 80/80 - 103s - loss: 0.3910 - accuracy: 0.8413 - val_loss: 0.2570 - val_accuracy: 0.9100 - 103s/epoch - 1s/step
# Epoch 6/50
# 80/80 - 102s - loss: 0.3866 - accuracy: 0.8425 - val_loss: 0.2489 - val_accuracy: 0.9250 - 102s/epoch - 1s/step
# Epoch 7/50
# 80/80 - 102s - loss: 0.3569 - accuracy: 0.8662 - val_loss: 0.2355 - val_accuracy: 0.9200 - 102s/epoch - 1s/step
# Epoch 8/50
# 80/80 - 102s - loss: 0.3460 - accuracy: 0.8650 - val_loss: 0.2345 - val_accuracy: 0.9200 - 102s/epoch - 1s/step
# Epoch 9/50
# 80/80 - 91s - loss: 0.3416 - accuracy: 0.8650 - val_loss: 0.2237 - val_accuracy: 0.9100 - 91s/epoch - 1s/step
# Epoch 10/50
# 80/80 - 72s - loss: 0.3335 - accuracy: 0.8687 - val_loss: 0.2155 - val_accuracy: 0.9300 - 72s/epoch - 900ms/step
# Epoch 11/50
# 80/80 - 72s - loss: 0.3071 - accuracy: 0.8925 - val_loss: 0.2100 - val_accuracy: 0.9250 - 72s/epoch - 897ms/step
# Epoch 12/50
# 80/80 - 72s - loss: 0.2919 - accuracy: 0.8888 - val_loss: 0.1950 - val_accuracy: 0.9250 - 72s/epoch - 894ms/step
# Epoch 13/50
# 80/80 - 69s - loss: 0.3171 - accuracy: 0.8675 - val_loss: 0.2178 - val_accuracy: 0.9300 - 69s/epoch - 858ms/step
# Epoch 14/50
# 80/80 - 45s - loss: 0.2953 - accuracy: 0.8938 - val_loss: 0.2041 - val_accuracy: 0.9300 - 45s/epoch - 567ms/step
# Epoch 15/50
# 80/80 - 45s - loss: 0.2922 - accuracy: 0.8888 - val_loss: 0.1816 - val_accuracy: 0.9500 - 45s/epoch - 567ms/step
# Epoch 16/50
# 80/80 - 45s - loss: 0.2737 - accuracy: 0.8913 - val_loss: 0.1792 - val_accuracy: 0.9350 - 45s/epoch - 564ms/step
# Epoch 17/50
# 80/80 - 45s - loss: 0.2539 - accuracy: 0.8975 - val_loss: 0.1630 - val_accuracy: 0.9350 - 45s/epoch - 567ms/step
# Epoch 18/50
# 80/80 - 45s - loss: 0.2517 - accuracy: 0.9087 - val_loss: 0.1996 - val_accuracy: 0.9250 - 45s/epoch - 565ms/step
# Epoch 19/50
# 80/80 - 45s - loss: 0.2240 - accuracy: 0.9237 - val_loss: 0.1466 - val_accuracy: 0.9600 - 45s/epoch - 564ms/step
# Epoch 20/50
# 80/80 - 45s - loss: 0.2408 - accuracy: 0.9000 - val_loss: 0.1701 - val_accuracy: 0.9550 - 45s/epoch - 567ms/step
# Epoch 21/50
# 80/80 - 45s - loss: 0.2379 - accuracy: 0.9200 - val_loss: 0.1574 - val_accuracy: 0.9450 - 45s/epoch - 565ms/step
# Epoch 22/50
# 80/80 - 45s - loss: 0.2367 - accuracy: 0.9125 - val_loss: 0.1361 - val_accuracy: 0.9600 - 45s/epoch - 565ms/step
# Epoch 23/50
# 80/80 - 45s - loss: 0.2015 - accuracy: 0.9250 - val_loss: 0.1609 - val_accuracy: 0.9350 - 45s/epoch - 565ms/step
# Epoch 24/50
# 80/80 - 45s - loss: 0.2179 - accuracy: 0.9200 - val_loss: 0.1524 - val_accuracy: 0.9600 - 45s/epoch - 564ms/step
# Epoch 25/50
# 80/80 - 45s - loss: 0.2091 - accuracy: 0.9287 - val_loss: 0.1489 - val_accuracy: 0.9550 - 45s/epoch - 562ms/step
# Epoch 26/50
# 80/80 - 45s - loss: 0.2007 - accuracy: 0.9300 - val_loss: 0.1360 - val_accuracy: 0.9600 - 45s/epoch - 563ms/step
# Epoch 27/50
# 80/80 - 45s - loss: 0.2184 - accuracy: 0.9225 - val_loss: 0.1628 - val_accuracy: 0.9300 - 45s/epoch - 563ms/step
# Epoch 28/50
# 80/80 - 45s - loss: 0.2175 - accuracy: 0.9225 - val_loss: 0.1190 - val_accuracy: 0.9600 - 45s/epoch - 562ms/step
# Epoch 29/50
# 80/80 - 45s - loss: 0.1959 - accuracy: 0.9312 - val_loss: 0.1499 - val_accuracy: 0.9300 - 45s/epoch - 563ms/step
# Epoch 30/50
# 80/80 - 45s - loss: 0.2282 - accuracy: 0.9112 - val_loss: 0.1464 - val_accuracy: 0.9500 - 45s/epoch - 562ms/step
# Epoch 31/50
# 80/80 - 45s - loss: 0.1987 - accuracy: 0.9287 - val_loss: 0.1343 - val_accuracy: 0.9600 - 45s/epoch - 564ms/step
# Epoch 32/50
# 80/80 - 45s - loss: 0.1743 - accuracy: 0.9350 - val_loss: 0.2012 - val_accuracy: 0.9300 - 45s/epoch - 560ms/step
# Epoch 33/50
# 80/80 - 45s - loss: 0.1954 - accuracy: 0.9287 - val_loss: 0.1334 - val_accuracy: 0.9600 - 45s/epoch - 563ms/step
# Epoch 34/50
# 80/80 - 45s - loss: 0.1802 - accuracy: 0.9350 - val_loss: 0.1213 - val_accuracy: 0.9600 - 45s/epoch - 562ms/step
# Epoch 35/50
# 80/80 - 45s - loss: 0.1761 - accuracy: 0.9350 - val_loss: 0.1638 - val_accuracy: 0.9650 - 45s/epoch - 562ms/step
# Epoch 36/50
# 80/80 - 45s - loss: 0.1653 - accuracy: 0.9375 - val_loss: 0.1285 - val_accuracy: 0.9550 - 45s/epoch - 564ms/step
# Epoch 37/50
# 80/80 - 45s - loss: 0.1813 - accuracy: 0.9413 - val_loss: 0.1211 - val_accuracy: 0.9400 - 45s/epoch - 562ms/step
# Epoch 38/50
# 80/80 - 45s - loss: 0.1580 - accuracy: 0.9350 - val_loss: 0.1458 - val_accuracy: 0.9350 - 45s/epoch - 563ms/step
# Epoch 39/50
# 80/80 - 45s - loss: 0.1629 - accuracy: 0.9425 - val_loss: 0.1620 - val_accuracy: 0.9500 - 45s/epoch - 562ms/step
# Epoch 40/50
# 80/80 - 45s - loss: 0.1631 - accuracy: 0.9362 - val_loss: 0.1539 - val_accuracy: 0.9350 - 45s/epoch - 565ms/step
# Epoch 41/50
# 80/80 - 45s - loss: 0.1898 - accuracy: 0.9300 - val_loss: 0.1418 - val_accuracy: 0.9400 - 45s/epoch - 561ms/step
# Epoch 42/50
# 80/80 - 45s - loss: 0.1831 - accuracy: 0.9350 - val_loss: 0.1533 - val_accuracy: 0.9400 - 45s/epoch - 564ms/step
# Epoch 43/50
# 80/80 - 45s - loss: 0.1530 - accuracy: 0.9438 - val_loss: 0.1799 - val_accuracy: 0.9250 - 45s/epoch - 562ms/step
# Epoch 44/50
# 80/80 - 45s - loss: 0.1386 - accuracy: 0.9513 - val_loss: 0.1465 - val_accuracy: 0.9450 - 45s/epoch - 561ms/step
# Epoch 45/50
# 80/80 - 45s - loss: 0.2024 - accuracy: 0.9200 - val_loss: 0.2297 - val_accuracy: 0.9100 - 45s/epoch - 563ms/step
# Epoch 46/50
# 80/80 - 45s - loss: 0.1792 - accuracy: 0.9400 - val_loss: 0.1541 - val_accuracy: 0.9350 - 45s/epoch - 563ms/step
# Epoch 47/50
# 80/80 - 45s - loss: 0.1411 - accuracy: 0.9575 - val_loss: 0.1491 - val_accuracy: 0.9500 - 45s/epoch - 564ms/step
# Epoch 48/50
# 80/80 - 45s - loss: 0.1549 - accuracy: 0.9413 - val_loss: 0.1584 - val_accuracy: 0.9400 - 45s/epoch - 563ms/step
# Epoch 49/50
# 80/80 - 45s - loss: 0.2055 - accuracy: 0.9300 - val_loss: 0.1644 - val_accuracy: 0.9450 - 45s/epoch - 562ms/step
# Epoch 50/50
# 80/80 - 45s - loss: 0.1512 - accuracy: 0.9525 - val_loss: 0.1469 - val_accuracy: 0.9400 - 45s/epoch - 563ms/step
# ########## Fold 1 accuracy: 0.9649999737739563 ##########
# ########## Fold 2 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 80/80 - 45s - loss: 0.6967 - accuracy: 0.5375 - val_loss: 0.6911 - val_accuracy: 0.5000 - 45s/epoch - 565ms/step
# Epoch 2/50
# 80/80 - 45s - loss: 0.6075 - accuracy: 0.6388 - val_loss: 0.4910 - val_accuracy: 0.7900 - 45s/epoch - 562ms/step
# Epoch 3/50
# 80/80 - 45s - loss: 0.4373 - accuracy: 0.8200 - val_loss: 0.5020 - val_accuracy: 0.7950 - 45s/epoch - 565ms/step
# Epoch 4/50
# 80/80 - 45s - loss: 0.3904 - accuracy: 0.8487 - val_loss: 0.3924 - val_accuracy: 0.8350 - 45s/epoch - 563ms/step
# Epoch 5/50
# 80/80 - 45s - loss: 0.3637 - accuracy: 0.8587 - val_loss: 0.3859 - val_accuracy: 0.8350 - 45s/epoch - 565ms/step
# Epoch 6/50
# 80/80 - 45s - loss: 0.3472 - accuracy: 0.8675 - val_loss: 0.3872 - val_accuracy: 0.8300 - 45s/epoch - 562ms/step
# Epoch 7/50
# 80/80 - 45s - loss: 0.3333 - accuracy: 0.8775 - val_loss: 0.4266 - val_accuracy: 0.8200 - 45s/epoch - 564ms/step
# Epoch 8/50
# 80/80 - 45s - loss: 0.3079 - accuracy: 0.8838 - val_loss: 0.3928 - val_accuracy: 0.8350 - 45s/epoch - 565ms/step
# Epoch 9/50
# 80/80 - 45s - loss: 0.2956 - accuracy: 0.8913 - val_loss: 0.3772 - val_accuracy: 0.8450 - 45s/epoch - 564ms/step
# Epoch 10/50
# 80/80 - 45s - loss: 0.3030 - accuracy: 0.8825 - val_loss: 0.3803 - val_accuracy: 0.8500 - 45s/epoch - 564ms/step
# Epoch 11/50
# 80/80 - 45s - loss: 0.2795 - accuracy: 0.9038 - val_loss: 0.3589 - val_accuracy: 0.8700 - 45s/epoch - 565ms/step
# Epoch 12/50
# 80/80 - 45s - loss: 0.2750 - accuracy: 0.9025 - val_loss: 0.3567 - val_accuracy: 0.8650 - 45s/epoch - 561ms/step
# Epoch 13/50
# 80/80 - 45s - loss: 0.2811 - accuracy: 0.8963 - val_loss: 0.3539 - val_accuracy: 0.8600 - 45s/epoch - 562ms/step
# Epoch 14/50
# 80/80 - 45s - loss: 0.2720 - accuracy: 0.9062 - val_loss: 0.3424 - val_accuracy: 0.8600 - 45s/epoch - 562ms/step
# Epoch 15/50
# 80/80 - 45s - loss: 0.2613 - accuracy: 0.9050 - val_loss: 0.3574 - val_accuracy: 0.8650 - 45s/epoch - 561ms/step
# Epoch 16/50
# 80/80 - 45s - loss: 0.2629 - accuracy: 0.9050 - val_loss: 0.3853 - val_accuracy: 0.8600 - 45s/epoch - 560ms/step
# Epoch 17/50
# 80/80 - 45s - loss: 0.2860 - accuracy: 0.8888 - val_loss: 0.3417 - val_accuracy: 0.8800 - 45s/epoch - 561ms/step
# Epoch 18/50
# 80/80 - 45s - loss: 0.2510 - accuracy: 0.9137 - val_loss: 0.3236 - val_accuracy: 0.8950 - 45s/epoch - 563ms/step
# Epoch 19/50
# 80/80 - 45s - loss: 0.2460 - accuracy: 0.9137 - val_loss: 0.3299 - val_accuracy: 0.8700 - 45s/epoch - 561ms/step
# Epoch 20/50
# 80/80 - 45s - loss: 0.2189 - accuracy: 0.9325 - val_loss: 0.3122 - val_accuracy: 0.8750 - 45s/epoch - 563ms/step
# Epoch 21/50
# 80/80 - 45s - loss: 0.2172 - accuracy: 0.9262 - val_loss: 0.3139 - val_accuracy: 0.8750 - 45s/epoch - 560ms/step
# Epoch 22/50
# 80/80 - 45s - loss: 0.2280 - accuracy: 0.9162 - val_loss: 0.3310 - val_accuracy: 0.8600 - 45s/epoch - 563ms/step
# Epoch 23/50
# 80/80 - 45s - loss: 0.2159 - accuracy: 0.9275 - val_loss: 0.2992 - val_accuracy: 0.8850 - 45s/epoch - 562ms/step
# Epoch 24/50
# 80/80 - 45s - loss: 0.2052 - accuracy: 0.9200 - val_loss: 0.2951 - val_accuracy: 0.8850 - 45s/epoch - 557ms/step
# Epoch 25/50
# 80/80 - 45s - loss: 0.1979 - accuracy: 0.9312 - val_loss: 0.2928 - val_accuracy: 0.8900 - 45s/epoch - 562ms/step
# Epoch 26/50
# 80/80 - 45s - loss: 0.1812 - accuracy: 0.9337 - val_loss: 0.3290 - val_accuracy: 0.8800 - 45s/epoch - 562ms/step
# Epoch 27/50
# 80/80 - 45s - loss: 0.2174 - accuracy: 0.9137 - val_loss: 0.3145 - val_accuracy: 0.8800 - 45s/epoch - 564ms/step
# Epoch 28/50
# 80/80 - 45s - loss: 0.1958 - accuracy: 0.9350 - val_loss: 0.2833 - val_accuracy: 0.8850 - 45s/epoch - 564ms/step
# Epoch 29/50
# 80/80 - 45s - loss: 0.1893 - accuracy: 0.9337 - val_loss: 0.3371 - val_accuracy: 0.8650 - 45s/epoch - 562ms/step
# Epoch 30/50
# 80/80 - 45s - loss: 0.1950 - accuracy: 0.9300 - val_loss: 0.3580 - val_accuracy: 0.8600 - 45s/epoch - 560ms/step
# Epoch 31/50
# 80/80 - 45s - loss: 0.1832 - accuracy: 0.9262 - val_loss: 0.2856 - val_accuracy: 0.8950 - 45s/epoch - 562ms/step
# Epoch 32/50
# 80/80 - 45s - loss: 0.2004 - accuracy: 0.9287 - val_loss: 0.2565 - val_accuracy: 0.9000 - 45s/epoch - 563ms/step
# Epoch 33/50
# 80/80 - 45s - loss: 0.1849 - accuracy: 0.9375 - val_loss: 0.4028 - val_accuracy: 0.8450 - 45s/epoch - 562ms/step
# Epoch 34/50
# 80/80 - 45s - loss: 0.1767 - accuracy: 0.9388 - val_loss: 0.2863 - val_accuracy: 0.8950 - 45s/epoch - 562ms/step
# Epoch 35/50
# 80/80 - 45s - loss: 0.1808 - accuracy: 0.9325 - val_loss: 0.2889 - val_accuracy: 0.8800 - 45s/epoch - 561ms/step
# Epoch 36/50
# 80/80 - 45s - loss: 0.1714 - accuracy: 0.9475 - val_loss: 0.2700 - val_accuracy: 0.8950 - 45s/epoch - 565ms/step
# Epoch 37/50
# 80/80 - 45s - loss: 0.1680 - accuracy: 0.9375 - val_loss: 0.2873 - val_accuracy: 0.8950 - 45s/epoch - 562ms/step
# Epoch 38/50
# 80/80 - 45s - loss: 0.1568 - accuracy: 0.9475 - val_loss: 0.2678 - val_accuracy: 0.8900 - 45s/epoch - 566ms/step
# Epoch 39/50
# 80/80 - 45s - loss: 0.1603 - accuracy: 0.9388 - val_loss: 0.2651 - val_accuracy: 0.9100 - 45s/epoch - 561ms/step
# Epoch 40/50
# 80/80 - 45s - loss: 0.2048 - accuracy: 0.9275 - val_loss: 0.3877 - val_accuracy: 0.8500 - 45s/epoch - 564ms/step
# Epoch 41/50
# 80/80 - 45s - loss: 0.1872 - accuracy: 0.9362 - val_loss: 0.2980 - val_accuracy: 0.8900 - 45s/epoch - 564ms/step
# Epoch 42/50
# 80/80 - 45s - loss: 0.1866 - accuracy: 0.9275 - val_loss: 0.2840 - val_accuracy: 0.8950 - 45s/epoch - 563ms/step
# Epoch 43/50
# 80/80 - 45s - loss: 0.1612 - accuracy: 0.9438 - val_loss: 0.2895 - val_accuracy: 0.8800 - 45s/epoch - 566ms/step
# Epoch 44/50
# 80/80 - 45s - loss: 0.1579 - accuracy: 0.9525 - val_loss: 0.2884 - val_accuracy: 0.9050 - 45s/epoch - 562ms/step
# Epoch 45/50
# 80/80 - 45s - loss: 0.1428 - accuracy: 0.9450 - val_loss: 0.2779 - val_accuracy: 0.9050 - 45s/epoch - 562ms/step
# Epoch 46/50
# 80/80 - 45s - loss: 0.1253 - accuracy: 0.9613 - val_loss: 0.2862 - val_accuracy: 0.8850 - 45s/epoch - 564ms/step
# Epoch 47/50
# 80/80 - 45s - loss: 0.1238 - accuracy: 0.9613 - val_loss: 0.2643 - val_accuracy: 0.9400 - 45s/epoch - 566ms/step
# Epoch 48/50
# 80/80 - 45s - loss: 0.1076 - accuracy: 0.9625 - val_loss: 0.3932 - val_accuracy: 0.8850 - 45s/epoch - 563ms/step
# Epoch 49/50
# 80/80 - 45s - loss: 0.1452 - accuracy: 0.9513 - val_loss: 0.2919 - val_accuracy: 0.9200 - 45s/epoch - 563ms/step
# Epoch 50/50
# 80/80 - 45s - loss: 0.1341 - accuracy: 0.9550 - val_loss: 0.3533 - val_accuracy: 0.8950 - 45s/epoch - 563ms/step
# ########## Fold 2 accuracy: 0.9399999976158142 ##########
# ########## Fold 3 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 80/80 - 45s - loss: 0.6939 - accuracy: 0.4625 - val_loss: 0.6931 - val_accuracy: 0.5000 - 45s/epoch - 568ms/step
# Epoch 2/50
# 80/80 - 45s - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6925 - val_accuracy: 0.5000 - 45s/epoch - 566ms/step
# Epoch 3/50
# 80/80 - 45s - loss: 0.6772 - accuracy: 0.6313 - val_loss: 0.5938 - val_accuracy: 0.7350 - 45s/epoch - 562ms/step
# Epoch 4/50
# 80/80 - 45s - loss: 0.4900 - accuracy: 0.7862 - val_loss: 0.4348 - val_accuracy: 0.8250 - 45s/epoch - 560ms/step
# Epoch 5/50
# 80/80 - 45s - loss: 0.3589 - accuracy: 0.8625 - val_loss: 0.4368 - val_accuracy: 0.8400 - 45s/epoch - 563ms/step
# Epoch 6/50
# 80/80 - 45s - loss: 0.3473 - accuracy: 0.8662 - val_loss: 0.4079 - val_accuracy: 0.8500 - 45s/epoch - 562ms/step
# Epoch 7/50
# 80/80 - 45s - loss: 0.3272 - accuracy: 0.8737 - val_loss: 0.3817 - val_accuracy: 0.8550 - 45s/epoch - 566ms/step
# Epoch 8/50
# 80/80 - 45s - loss: 0.3351 - accuracy: 0.8650 - val_loss: 0.4161 - val_accuracy: 0.8200 - 45s/epoch - 562ms/step
# Epoch 9/50
# 80/80 - 45s - loss: 0.2952 - accuracy: 0.8863 - val_loss: 0.3718 - val_accuracy: 0.8600 - 45s/epoch - 566ms/step
# Epoch 10/50
# 80/80 - 45s - loss: 0.2953 - accuracy: 0.8925 - val_loss: 0.3932 - val_accuracy: 0.8450 - 45s/epoch - 562ms/step
# Epoch 11/50
# 80/80 - 45s - loss: 0.2997 - accuracy: 0.8900 - val_loss: 0.3578 - val_accuracy: 0.8800 - 45s/epoch - 561ms/step
# Epoch 12/50
# 80/80 - 45s - loss: 0.2740 - accuracy: 0.9038 - val_loss: 0.3537 - val_accuracy: 0.8800 - 45s/epoch - 562ms/step
# Epoch 13/50
# 80/80 - 45s - loss: 0.2647 - accuracy: 0.9013 - val_loss: 0.3808 - val_accuracy: 0.8350 - 45s/epoch - 561ms/step
# Epoch 14/50
# 80/80 - 45s - loss: 0.2476 - accuracy: 0.9100 - val_loss: 0.3915 - val_accuracy: 0.8550 - 45s/epoch - 563ms/step
# Epoch 15/50
# 80/80 - 45s - loss: 0.2869 - accuracy: 0.8988 - val_loss: 0.3445 - val_accuracy: 0.8850 - 45s/epoch - 563ms/step
# Epoch 16/50
# 80/80 - 45s - loss: 0.2367 - accuracy: 0.9112 - val_loss: 0.3323 - val_accuracy: 0.8950 - 45s/epoch - 566ms/step
# Epoch 17/50
# 80/80 - 45s - loss: 0.2242 - accuracy: 0.9175 - val_loss: 0.3237 - val_accuracy: 0.8950 - 45s/epoch - 564ms/step
# Epoch 18/50
# 80/80 - 45s - loss: 0.2008 - accuracy: 0.9237 - val_loss: 0.3129 - val_accuracy: 0.8800 - 45s/epoch - 565ms/step
# Epoch 19/50
# 80/80 - 45s - loss: 0.2379 - accuracy: 0.9125 - val_loss: 0.3149 - val_accuracy: 0.8950 - 45s/epoch - 566ms/step
# Epoch 20/50
# 80/80 - 45s - loss: 0.2125 - accuracy: 0.9250 - val_loss: 0.3081 - val_accuracy: 0.8950 - 45s/epoch - 566ms/step
# Epoch 21/50
# 80/80 - 45s - loss: 0.2457 - accuracy: 0.9150 - val_loss: 0.3433 - val_accuracy: 0.8700 - 45s/epoch - 568ms/step
# Epoch 22/50
# 80/80 - 45s - loss: 0.2185 - accuracy: 0.9225 - val_loss: 0.3418 - val_accuracy: 0.8900 - 45s/epoch - 567ms/step
# Epoch 23/50
# 80/80 - 45s - loss: 0.2033 - accuracy: 0.9275 - val_loss: 0.3270 - val_accuracy: 0.8950 - 45s/epoch - 564ms/step
# Epoch 24/50
# 80/80 - 45s - loss: 0.1745 - accuracy: 0.9425 - val_loss: 0.3338 - val_accuracy: 0.8800 - 45s/epoch - 564ms/step
# Epoch 25/50
# 80/80 - 45s - loss: 0.1939 - accuracy: 0.9312 - val_loss: 0.3892 - val_accuracy: 0.8650 - 45s/epoch - 566ms/step
# Epoch 26/50
# 80/80 - 45s - loss: 0.1908 - accuracy: 0.9337 - val_loss: 0.2918 - val_accuracy: 0.9000 - 45s/epoch - 565ms/step
# Epoch 27/50
# 80/80 - 45s - loss: 0.1728 - accuracy: 0.9450 - val_loss: 0.3281 - val_accuracy: 0.8950 - 45s/epoch - 566ms/step
# Epoch 28/50
# 80/80 - 45s - loss: 0.1699 - accuracy: 0.9375 - val_loss: 0.2913 - val_accuracy: 0.9100 - 45s/epoch - 565ms/step
# Epoch 29/50
# 80/80 - 45s - loss: 0.1476 - accuracy: 0.9525 - val_loss: 0.2866 - val_accuracy: 0.9050 - 45s/epoch - 563ms/step
# Epoch 30/50
# 80/80 - 45s - loss: 0.1469 - accuracy: 0.9488 - val_loss: 0.3105 - val_accuracy: 0.9150 - 45s/epoch - 565ms/step
# Epoch 31/50
# 80/80 - 45s - loss: 0.1698 - accuracy: 0.9375 - val_loss: 0.3241 - val_accuracy: 0.9000 - 45s/epoch - 566ms/step
# Epoch 32/50
# 80/80 - 45s - loss: 0.1373 - accuracy: 0.9550 - val_loss: 0.2806 - val_accuracy: 0.9150 - 45s/epoch - 564ms/step
# Epoch 33/50
# 80/80 - 45s - loss: 0.1346 - accuracy: 0.9563 - val_loss: 0.2834 - val_accuracy: 0.9250 - 45s/epoch - 566ms/step
# Epoch 34/50
# 80/80 - 45s - loss: 0.1510 - accuracy: 0.9450 - val_loss: 0.2791 - val_accuracy: 0.9200 - 45s/epoch - 566ms/step
# Epoch 35/50
# 80/80 - 45s - loss: 0.1254 - accuracy: 0.9588 - val_loss: 0.2993 - val_accuracy: 0.9100 - 45s/epoch - 565ms/step
# Epoch 36/50
# 80/80 - 45s - loss: 0.1888 - accuracy: 0.9287 - val_loss: 0.2922 - val_accuracy: 0.9050 - 45s/epoch - 565ms/step
# Epoch 37/50
# 80/80 - 45s - loss: 0.1276 - accuracy: 0.9613 - val_loss: 0.2534 - val_accuracy: 0.9350 - 45s/epoch - 565ms/step
# Epoch 38/50
# 80/80 - 45s - loss: 0.1239 - accuracy: 0.9613 - val_loss: 0.3154 - val_accuracy: 0.9150 - 45s/epoch - 565ms/step
# Epoch 39/50
# 80/80 - 45s - loss: 0.1352 - accuracy: 0.9500 - val_loss: 0.2666 - val_accuracy: 0.9250 - 45s/epoch - 565ms/step
# Epoch 40/50
# 80/80 - 45s - loss: 0.1093 - accuracy: 0.9688 - val_loss: 0.4356 - val_accuracy: 0.8450 - 45s/epoch - 564ms/step
# Epoch 41/50
# 80/80 - 46s - loss: 0.1258 - accuracy: 0.9600 - val_loss: 0.2835 - val_accuracy: 0.9050 - 46s/epoch - 570ms/step
# Epoch 42/50
# 80/80 - 45s - loss: 0.1541 - accuracy: 0.9438 - val_loss: 0.4338 - val_accuracy: 0.8550 - 45s/epoch - 566ms/step
# Epoch 43/50
# 80/80 - 45s - loss: 0.1451 - accuracy: 0.9513 - val_loss: 0.2813 - val_accuracy: 0.9200 - 45s/epoch - 567ms/step
# Epoch 44/50
# 80/80 - 45s - loss: 0.1159 - accuracy: 0.9688 - val_loss: 0.3117 - val_accuracy: 0.9000 - 45s/epoch - 564ms/step
# Epoch 45/50
# 80/80 - 45s - loss: 0.1174 - accuracy: 0.9638 - val_loss: 0.3204 - val_accuracy: 0.9050 - 45s/epoch - 563ms/step
# Epoch 46/50
# 80/80 - 45s - loss: 0.1364 - accuracy: 0.9525 - val_loss: 0.3900 - val_accuracy: 0.8850 - 45s/epoch - 565ms/step
# Epoch 47/50
# 80/80 - 45s - loss: 0.1320 - accuracy: 0.9513 - val_loss: 0.2890 - val_accuracy: 0.9150 - 45s/epoch - 565ms/step
# Epoch 48/50
# 80/80 - 45s - loss: 0.0919 - accuracy: 0.9700 - val_loss: 0.2882 - val_accuracy: 0.9150 - 45s/epoch - 568ms/step
# Epoch 49/50
# 80/80 - 45s - loss: 0.0869 - accuracy: 0.9712 - val_loss: 0.2851 - val_accuracy: 0.9250 - 45s/epoch - 565ms/step
# Epoch 50/50
# 80/80 - 45s - loss: 0.0979 - accuracy: 0.9712 - val_loss: 0.2763 - val_accuracy: 0.9300 - 45s/epoch - 566ms/step
# ########## Fold 3 accuracy: 0.9350000023841858 ##########
# ########## Fold 4 ##########
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 80/80 - 46s - loss: 0.7020 - accuracy: 0.4750 - val_loss: 0.6930 - val_accuracy: 0.5000 - 46s/epoch - 572ms/step
# Epoch 2/50
# 80/80 - 45s - loss: 0.6297 - accuracy: 0.6075 - val_loss: 0.4737 - val_accuracy: 0.7800 - 45s/epoch - 564ms/step
# Epoch 3/50
# 80/80 - 45s - loss: 0.4835 - accuracy: 0.7800 - val_loss: 0.4626 - val_accuracy: 0.8200 - 45s/epoch - 564ms/step
# Epoch 4/50
# 80/80 - 45s - loss: 0.4107 - accuracy: 0.8250 - val_loss: 0.3393 - val_accuracy: 0.8700 - 45s/epoch - 566ms/step
# Epoch 5/50
# 80/80 - 45s - loss: 0.3939 - accuracy: 0.8450 - val_loss: 0.3380 - val_accuracy: 0.8750 - 45s/epoch - 563ms/step
# Epoch 6/50
# 80/80 - 45s - loss: 0.3647 - accuracy: 0.8650 - val_loss: 0.3052 - val_accuracy: 0.8750 - 45s/epoch - 565ms/step
# Epoch 7/50
# 80/80 - 45s - loss: 0.3336 - accuracy: 0.8712 - val_loss: 0.3614 - val_accuracy: 0.8600 - 45s/epoch - 565ms/step
# Epoch 8/50
# 80/80 - 45s - loss: 0.3317 - accuracy: 0.8687 - val_loss: 0.2923 - val_accuracy: 0.8850 - 45s/epoch - 566ms/step
# Epoch 9/50
# 80/80 - 45s - loss: 0.3085 - accuracy: 0.8750 - val_loss: 0.3076 - val_accuracy: 0.8800 - 45s/epoch - 565ms/step
# Epoch 10/50
# 80/80 - 45s - loss: 0.3294 - accuracy: 0.8700 - val_loss: 0.2686 - val_accuracy: 0.8950 - 45s/epoch - 566ms/step
# Epoch 11/50
# 80/80 - 45s - loss: 0.2855 - accuracy: 0.8863 - val_loss: 0.2951 - val_accuracy: 0.8750 - 45s/epoch - 566ms/step
# Epoch 12/50
# 80/80 - 45s - loss: 0.3058 - accuracy: 0.8775 - val_loss: 0.2675 - val_accuracy: 0.8900 - 45s/epoch - 566ms/step
# Epoch 13/50
# 80/80 - 45s - loss: 0.2797 - accuracy: 0.9038 - val_loss: 0.3036 - val_accuracy: 0.8800 - 45s/epoch - 564ms/step
# Epoch 14/50
# 80/80 - 45s - loss: 0.2687 - accuracy: 0.9025 - val_loss: 0.2254 - val_accuracy: 0.9150 - 45s/epoch - 565ms/step
# Epoch 15/50
# 80/80 - 45s - loss: 0.2358 - accuracy: 0.9162 - val_loss: 0.2310 - val_accuracy: 0.9300 - 45s/epoch - 566ms/step
# Epoch 16/50
# 80/80 - 45s - loss: 0.2551 - accuracy: 0.9038 - val_loss: 0.2703 - val_accuracy: 0.8800 - 45s/epoch - 564ms/step
# Epoch 17/50
# 80/80 - 45s - loss: 0.2214 - accuracy: 0.9187 - val_loss: 0.2257 - val_accuracy: 0.9200 - 45s/epoch - 567ms/step
# Epoch 18/50
# 80/80 - 45s - loss: 0.2227 - accuracy: 0.9137 - val_loss: 0.2291 - val_accuracy: 0.9150 - 45s/epoch - 566ms/step
# Epoch 19/50
# 80/80 - 45s - loss: 0.2041 - accuracy: 0.9250 - val_loss: 0.2664 - val_accuracy: 0.9000 - 45s/epoch - 564ms/step
# Epoch 20/50
# 80/80 - 45s - loss: 0.1945 - accuracy: 0.9312 - val_loss: 0.3122 - val_accuracy: 0.8700 - 45s/epoch - 567ms/step
# Epoch 21/50
# 80/80 - 45s - loss: 0.2280 - accuracy: 0.9112 - val_loss: 0.2148 - val_accuracy: 0.9200 - 45s/epoch - 565ms/step
# Epoch 22/50
# 80/80 - 45s - loss: 0.1901 - accuracy: 0.9312 - val_loss: 0.2348 - val_accuracy: 0.9050 - 45s/epoch - 567ms/step
# Epoch 23/50
# 80/80 - 45s - loss: 0.1814 - accuracy: 0.9388 - val_loss: 0.2251 - val_accuracy: 0.8950 - 45s/epoch - 565ms/step
# Epoch 24/50
# 80/80 - 45s - loss: 0.1684 - accuracy: 0.9438 - val_loss: 0.2174 - val_accuracy: 0.9250 - 45s/epoch - 562ms/step
# Epoch 25/50
# 80/80 - 45s - loss: 0.1992 - accuracy: 0.9287 - val_loss: 0.2153 - val_accuracy: 0.9300 - 45s/epoch - 564ms/step
# Epoch 26/50
# 80/80 - 45s - loss: 0.1680 - accuracy: 0.9400 - val_loss: 0.2259 - val_accuracy: 0.9150 - 45s/epoch - 564ms/step
# Epoch 27/50
# 80/80 - 45s - loss: 0.1720 - accuracy: 0.9425 - val_loss: 0.2348 - val_accuracy: 0.9050 - 45s/epoch - 566ms/step
# Epoch 28/50
# 80/80 - 45s - loss: 0.1678 - accuracy: 0.9438 - val_loss: 0.2077 - val_accuracy: 0.9350 - 45s/epoch - 565ms/step
# Epoch 29/50
# 80/80 - 45s - loss: 0.1399 - accuracy: 0.9500 - val_loss: 0.2223 - val_accuracy: 0.9300 - 45s/epoch - 564ms/step
# Epoch 30/50
# 80/80 - 45s - loss: 0.1468 - accuracy: 0.9525 - val_loss: 0.2454 - val_accuracy: 0.8950 - 45s/epoch - 564ms/step
# Epoch 31/50
# 80/80 - 45s - loss: 0.1395 - accuracy: 0.9563 - val_loss: 0.1993 - val_accuracy: 0.9200 - 45s/epoch - 564ms/step
# Epoch 32/50
# 80/80 - 45s - loss: 0.1630 - accuracy: 0.9438 - val_loss: 0.2489 - val_accuracy: 0.9200 - 45s/epoch - 567ms/step
# Epoch 33/50
# 80/80 - 45s - loss: 0.1417 - accuracy: 0.9525 - val_loss: 0.1957 - val_accuracy: 0.9150 - 45s/epoch - 566ms/step
# Epoch 34/50
# 80/80 - 45s - loss: 0.1266 - accuracy: 0.9613 - val_loss: 0.2066 - val_accuracy: 0.9200 - 45s/epoch - 566ms/step
# Epoch 35/50
# 80/80 - 45s - loss: 0.1114 - accuracy: 0.9675 - val_loss: 0.2255 - val_accuracy: 0.9100 - 45s/epoch - 567ms/step
# Epoch 36/50
# 80/80 - 45s - loss: 0.1075 - accuracy: 0.9663 - val_loss: 0.2021 - val_accuracy: 0.9350 - 45s/epoch - 564ms/step
# Epoch 37/50
# 80/80 - 45s - loss: 0.1320 - accuracy: 0.9563 - val_loss: 0.3835 - val_accuracy: 0.8450 - 45s/epoch - 566ms/step
# Epoch 38/50
# 80/80 - 45s - loss: 0.1369 - accuracy: 0.9500 - val_loss: 0.3036 - val_accuracy: 0.9050 - 45s/epoch - 563ms/step
# Epoch 39/50
# 80/80 - 45s - loss: 0.1387 - accuracy: 0.9525 - val_loss: 0.1975 - val_accuracy: 0.9400 - 45s/epoch - 563ms/step
# Epoch 40/50
# 80/80 - 45s - loss: 0.0803 - accuracy: 0.9750 - val_loss: 0.2309 - val_accuracy: 0.9250 - 45s/epoch - 566ms/step
# Epoch 41/50
# 80/80 - 45s - loss: 0.1128 - accuracy: 0.9688 - val_loss: 0.2203 - val_accuracy: 0.9200 - 45s/epoch - 567ms/step
# Epoch 42/50
# 80/80 - 45s - loss: 0.1204 - accuracy: 0.9625 - val_loss: 0.2024 - val_accuracy: 0.9200 - 45s/epoch - 563ms/step
# Epoch 43/50
# 80/80 - 45s - loss: 0.0853 - accuracy: 0.9712 - val_loss: 0.2506 - val_accuracy: 0.9200 - 45s/epoch - 563ms/step
# Epoch 44/50
# 80/80 - 45s - loss: 0.0691 - accuracy: 0.9825 - val_loss: 0.3603 - val_accuracy: 0.8800 - 45s/epoch - 567ms/step
# Epoch 45/50
# 80/80 - 45s - loss: 0.0899 - accuracy: 0.9725 - val_loss: 0.2927 - val_accuracy: 0.9050 - 45s/epoch - 564ms/step
# Epoch 46/50
# 80/80 - 46s - loss: 0.0653 - accuracy: 0.9837 - val_loss: 0.2790 - val_accuracy: 0.9200 - 46s/epoch - 569ms/step
# Epoch 47/50
# 80/80 - 45s - loss: 0.0801 - accuracy: 0.9737 - val_loss: 0.2292 - val_accuracy: 0.9100 - 45s/epoch - 568ms/step
# Epoch 48/50
# 80/80 - 45s - loss: 0.0665 - accuracy: 0.9812 - val_loss: 0.2387 - val_accuracy: 0.9250 - 45s/epoch - 561ms/step
# Epoch 49/50
# 80/80 - 45s - loss: 0.0638 - accuracy: 0.9812 - val_loss: 0.2522 - val_accuracy: 0.9150 - 45s/epoch - 566ms/step
# Epoch 50/50
# 80/80 - 45s - loss: 0.0654 - accuracy: 0.9787 - val_loss: 0.2587 - val_accuracy: 0.9150 - 45s/epoch - 562ms/step
# ########## Fold 4 accuracy: 0.9399999976158142 ##########

# %%
print('CV accuracy:', cv_acc)
# Out:
# CV accuracy: 0.9449999928474426
